# %% [markdown]
# # SURF, SIFT Descriptors

# %%
import cv2 as cv
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_folder1 = os.path.join(os.curdir,'dataset1(kvadr)')
data_set1 = [os.path.join(data_folder1,file) for file in os.listdir(data_folder1) if os.path.isfile(os.path.join(data_folder1,file))]
data_folder2 = os.path.join(os.curdir,'dataset2(pony)')
data_set2 = [os.path.join(data_folder2,file) for file in os.listdir(data_folder2) if os.path.isfile(os.path.join(data_folder2,file))]

# %%
kvadrs = [cv.imread(image,0) for image in data_set1]
ponies = [cv.imread(image,0) for image in data_set2]

# %%
data_set1
# Out:
# ['./dataset1(kvadr)/IMG_3091.JPG',
#  './dataset1(kvadr)/IMG_3380(1).jpg',
#  './dataset1(kvadr)/IMG_3050.jpg',
#  './dataset1(kvadr)/IMG_3350.JPG',
#  './dataset1(kvadr)/IMG_3097.jpg',
#  './dataset1(kvadr)/IMG_3053.jpg',
#  './dataset1(kvadr)/IMG_3391(1).JPG',
#  './dataset1(kvadr)/IMG_3062.jpg',
#  './dataset1(kvadr)/IMG_3533.JPG',
#  './dataset1(kvadr)/IMG_3059.jpg',
#  './dataset1(kvadr)/IMG_3391.JPG',
#  './dataset1(kvadr)/IMG_3056.jpg',
#  './dataset1(kvadr)/IMG_3109.JPG',
#  './dataset1(kvadr)/IMG_3187.jpg',
#  './dataset1(kvadr)/IMG_3060.jpg',
#  './dataset1(kvadr)/IMG_3124.jpg',
#  './dataset1(kvadr)/IMG_3130.JPG',
#  './dataset1(kvadr)/IMG_3065.jpg',
#  './dataset1(kvadr)/IMG_3358.JPG',
#  './dataset1(kvadr)/IMG_3499.JPG',
#  './dataset1(kvadr)/IMG_3178.JPG',
#  './dataset1(kvadr)/IMG_3353.JPG',
#  './dataset1(kvadr)/IMG_3365.jpg',
#  './dataset1(kvadr)/IMG_3075.JPG',
#  './dataset1(kvadr)/IMG_3366.JPG',
#  './dataset1(kvadr)/IMG_3063.jpg',
#  './dataset1(kvadr)/IMG_3415.JPG',
#  './dataset1(kvadr)/IMG_3070.jpg',
#  './dataset1(kvadr)/IMG_3545.JPG',
#  './dataset1(kvadr)/IMG_3046.jpg',
#  './dataset1(kvadr)/IMG_3047.jpg',
#  './dataset1(kvadr)/IMG_3379.JPG',
#  './dataset1(kvadr)/IMG_3393.JPG',
#  './dataset1(kvadr)/IMG_3055.jpg',
#  './dataset1(kvadr)/IMG_3115.JPG',
#  './dataset1(kvadr)/IMG_3183.JPG',
#  './dataset1(kvadr)/IMG_3343.JPG',
#  './dataset1(kvadr)/IMG_3052.jpg',
#  './dataset1(kvadr)/IMG_3186.JPG',
#  './dataset1(kvadr)/IMG_3064.jpg',
#  './dataset1(kvadr)/IMG_3162.jpg',
#  './dataset1(kvadr)/IMG_3364.jpg',
#  './dataset1(kvadr)/IMG_3045.jpg',
#  './dataset1(kvadr)/IMG_3123.JPG',
#  './dataset1(kvadr)/IMG_3380.jpg',
#  './dataset1(kvadr)/IMG_3054.jpg',
#  './dataset1(kvadr)/IMG_3051.jpg',
#  './dataset1(kvadr)/IMG_3486.JPG',
#  './dataset1(kvadr)/IMG_3508.JPG',
#  './dataset1(kvadr)/IMG_3199.JPG',
#  './dataset1(kvadr)/IMG_3044.jpg',
#  './dataset1(kvadr)/IMG_3081.JPG',
#  './dataset1(kvadr)/IMG_3163.JPG',
#  './dataset1(kvadr)/IMG_3125.JPG',
#  './dataset1(kvadr)/IMG_3342.jpg',
#  './dataset1(kvadr)/IMG_3392.jpg',
#  './dataset1(kvadr)/IMG_3559.JPG',
#  './dataset1(kvadr)/IMG_3189.JPG',
#  './dataset1(kvadr)/IMG_3573.JPG',
#  './dataset1(kvadr)/IMG_3098.JPG',
#  './dataset1(kvadr)/IMG_3517.JPG',
#  './dataset1(kvadr)/IMG_3058.jpg',
#  './dataset1(kvadr)/IMG_3094.JPG',
#  './dataset1(kvadr)/IMG_3066.jpg',
#  './dataset1(kvadr)/IMG_3057.jpg',
#  './dataset1(kvadr)/IMG_3173.JPG',
#  './dataset1(kvadr)/IMG_3069.jpg',
#  './dataset1(kvadr)/IMG_3043.jpg',
#  './dataset1(kvadr)/IMG_3552.JPG',
#  './dataset1(kvadr)/IMG_3489.JPG',
#  './dataset1(kvadr)/IMG_3402.JPG',
#  './dataset1(kvadr)/IMG_3154.JPG',
#  './dataset1(kvadr)/IMG_3372.JPG',
#  './dataset1(kvadr)/IMG_3067.jpg',
#  './dataset1(kvadr)/IMG_3061.jpg',
#  './dataset1(kvadr)/IMG_3135.JPG',
#  './dataset1(kvadr)/IMG_3161.JPG',
#  './dataset1(kvadr)/IMG_3188.jpg',
#  './dataset1(kvadr)/IMG_3143.JPG',
#  './dataset1(kvadr)/IMG_3472.jpg',
#  './dataset1(kvadr)/IMG_3445.JPG',
#  './dataset1(kvadr)/IMG_3426.JPG',
#  './dataset1(kvadr)/IMG_3348.JPG',
#  './dataset1(kvadr)/IMG_3525.JPG',
#  './dataset1(kvadr)/IMG_3473.JPG',
#  './dataset1(kvadr)/IMG_3068.jpg']

# %%
surf = cv.xfeatures2d.SURF_create(400)
kp1, des1 = surf.detectAndCompute(kvadrs[2],None)
kp2, des2 = surf.detectAndCompute(kvadrs[3],None)

# %%
img1 = cv.drawKeypoints(kvadrs[2],kp,None,(255,0,0),4)

plt.imshow(img1),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7fca1ccd3cd0>, None)

# %%
bf = cv.BFMatcher(cv.NORM_L2, crossCheck=True)
matches = bf.match(des1,des2)
matches = sorted(matches, key = lambda x:x.distance)
img3 = cv.drawMatches(kvadrs[2],kp1,kvadrs[3],kp2,matches[:10],None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7fca1cc13610>, None)
